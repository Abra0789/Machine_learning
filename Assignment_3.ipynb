# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pt
import seaborn as sns
from sklearn.model_selection import  train_test_split as tts

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, classification_report

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel("cancer.xlsx")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['diagnosis'] = le.fit_transform(df['diagnosis'])

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
x = df.drop('diagnosis', axis=1)

# %%
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
y = df[['diagnosis']]

# %%
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
xtrain, xtest, ytrain, ytest = tts(x,y, test_size=0.3, random_state=50)

# %% [markdown]
# # Decision Tree

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier()

# %%
pred_clf = clf.predict(xtest)

# %%
print(classification_report(ytest, pred_clf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93       112
#            1       0.84      0.90      0.87        59
#
#     accuracy                           0.91       171
#    macro avg       0.89      0.90      0.90       171
# weighted avg       0.91      0.91      0.91       171

# %%
mse = mean_squared_error(ytest, pred_clf)

# %%
mae = mean_absolute_error(ytest, pred_clf)

# %%
mse
# Out:
# 0.0935672514619883

# %%
mae
# Out:
# 0.0935672514619883

# %%
mse
mae
# Out:
# 0.0935672514619883

# %%
r2_score(ytest,pred_dt)
# Out:
# 0.663589588377724

# %% [markdown]
# # K Neighbour Algorithm

# %%
ag = KNeighborsClassifier()

# %%
ag.fit(xtrain, ytrain)
# Out:
# KNeighborsClassifier()

# %%
pred_ag = ag.predict(xtest)

# %%
print(classification_report(ytest, pred_ag))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       112
#            1       0.91      0.85      0.88        59
#
#     accuracy                           0.92       171
#    macro avg       0.92      0.90      0.91       171
# weighted avg       0.92      0.92      0.92       171

# %%
mse = mean_squared_error(ytest, pred_ag)

# %%
mae = mean_absolute_error(ytest, pred_ag)

# %%
mse
# Out:
# 0.08187134502923976

# %%
mae
# Out:
# 0.08187134502923976

# %%
r2_score(ytest,pred_ag)
# Out:
# 0.6377118644067796
