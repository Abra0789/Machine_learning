# %%
import numpy as np
import pandas as pd
import pickle as pk
import seaborn as sns
import gensim as gs
import sklearn.cluster as cluster
import string as st
from gensim.models import Word2Vec
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import RandomOverSampler
from kneed import KneeLocator
from matplotlib import pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.corpus import words
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize as stt
from nltk.tokenize import word_tokenize as wtt
from pandas.core.dtypes.common import is_numeric_dtype as is_num
import plotly.express as px
from sklearn import tree
from sklearn.cluster import KMeans
from sklearn.datasets import make_classification as mc
from sklearn.decomposition import PCA
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score as acc
from sklearn.metrics import classification_report as cr
from sklearn.metrics import confusion_matrix as cm
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split as tts 
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.svm import SVR

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Analysis

# %%
df = pd.read_excel('Heart Disease.xlsx')

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No               3
# 1           No  20.34      No              No    Yes               0
# 2           No  26.58     Yes              No     No              20
# 3           No  24.21      No              No     No               0
# 4           No  23.71      No              No     No              28
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0            30          No  Female        55-59  White      Yes
# 1             0          No  Female  80 or older  White       No
# 2            30          No    Male        65-69  White      Yes
# 3             0          No  Female        75-79  White       No
# 4             0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good          5    Yes            No        Yes
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  int64
#  6   MentalHealth      319795 non-null  int64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  int64
#  15  Asthma            319795 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.shape
# Out:
# (319795, 18)

# %%
df.duplicated().sum()
# Out:
# 18078

# %%
df.drop_duplicates(inplace = True)

# %%
df.dtypes
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth        int64
# MentalHealth          int64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime             int64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
df.corr(numeric_only = True)
# Out:
#                      BMI  PhysicalHealth  MentalHealth  SleepTime
# BMI             1.000000        0.103813      0.056724  -0.048653
# PhysicalHealth  0.103813        1.000000      0.279657  -0.058406
# MentalHealth    0.056724        0.279657      1.000000  -0.117078
# SleepTime      -0.048653       -0.058406     -0.117078   1.000000

# %%
df.nunique()
# Out:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DiffWalking            2
# Sex                    2
# AgeCategory           13
# Race                   6
# Diabetic               4
# PhysicalActivity       2
# GenHealth              5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %% [markdown]
# # VISUALIZATION

# %% [markdown]
# # Barplot

# %%
plt.figure(figsize = (15, 10))
sns.barplot(x = df['SleepTime'].value_counts().index, y = df['SleepTime'].value_counts().values, palette = 'rainbow', saturation = 1.0, errcolor = 'black', errwidth = 2.0, capsize = 0.2).set_title('Bmi-SleepTime Correlation', fontsize = 60, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', loc = 'center', pad = 10.0, weight = 'bold')
plt.xlabel('SleepTime', fontsize = 30, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', labelpad = 20)
plt.ylabel('BMI', fontsize = 30, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', labelpad = 20)
plt.xticks(fontsize = 20, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', rotation = 90)
plt.yticks(fontsize = 20, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black')
plt.show()

# %% [markdown]
# # Box Plot

# %%
plt.figure(figsize = (40, 30))
sns.boxplot(x = df['BMI'], y = df['SleepTime'], data = df, palette = 'rainbow', saturation = 1.0, width = 0.8, fliersize = 5.0, linewidth = 2.0, whis = 1.5).set_title('BMI-SleepTime Correlation', fontsize = 80, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', loc = 'center', pad = 10.0, weight = 'bold')
plt.xlabel('BMI', fontsize = 60, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', labelpad = 20)
plt.ylabel('SleepTime', fontsize = 60, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', labelpad = 20)
plt.xticks(fontsize = 40, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', rotation = 90)
plt.yticks(fontsize = 40, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black')
plt.show()

# %% [markdown]
# # Hisplot

# %%
plt.figure(figsize = (15, 10))
sns.histplot(df['BMI'], kde = True, color = 'pink', bins = 20, edgecolor = 'black', linewidth = 2, alpha = 0.8, label = 'BMI', element = 'step', fill = True).set_title('Count of Bmi Measurement', fontsize = 60, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', loc = 'center', pad = 20)
plt.xlabel('BMI', fontsize = 30, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', labelpad = 20)
plt.ylabel('Count', fontsize = 30, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', labelpad = 20)
plt.xticks(fontsize = 20, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', rotation = 90)
plt.yticks(fontsize = 20, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black')
plt.legend(loc = 'upper right', fontsize = 20, facecolor = 'white', edgecolor = 'black', framealpha = 0.9)
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
plt.figure(figsize = (40,20))
sns.scatterplot(x = df['PhysicalHealth'], y = df['MentalHealth'], data = df, palette = 'rainbow', hue = df['MentalHealth'], size = df['MentalHealth'], sizes = (10, 600), alpha = 0.5).set_title('Examining the link between Mental and Physical Health', fontsize = 60, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', loc = 'center', pad = 10.0, weight = 'bold')
plt.xlabel('PhysicalHealth', fontsize = 30, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', labelpad = 20)
plt.ylabel('MentalHealth', fontsize = 30, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', labelpad = 20)
plt.xticks(fontsize = 20, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', rotation = 90)
plt.yticks(fontsize = 20, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black')
plt.legend(loc = 'lower right', fontsize = 20, facecolor = 'gray', edgecolor = 'gray', framealpha = 0.6)
plt.show()

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize = (15, 10))
sns.heatmap(df.corr(numeric_only = True),annot = True, linewidth = 2.0, linecolor = 'gray', annot_kws = {'fontsize': 20, 'fontweight': 'bold', 'fontname': 'Freestyle Script', 'color': 'gray'}, fmt = '.2f', cbar = True, square = True).set_title('Correlation Heatmap', fontsize = 50, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', loc = 'center', pad = 10.0, weight = 'bold')
plt.xticks(fontsize = 30, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', rotation = 90)
plt.yticks(fontsize = 30, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', rotation = 0)
plt.show()

# %% [markdown]
# # Min-Max Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm = MinMaxScaler(feature_range = (0, 1))

# %%
df['BMI'] = mm.fit_transform(df[['BMI']])
df['PhysicalHealth'] = mm.fit_transform(df[['PhysicalHealth']])
df['MentalHealth'] = mm.fit_transform(df[['MentalHealth']])
df['SleepTime'] = mm.fit_transform(df[['SleepTime']])

# %%
df.head()
# Out:
#   HeartDisease       BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  0.055294     Yes              No     No        0.100000
# 1           No  0.100447      No              No    Yes        0.000000
# 2           No  0.175782     Yes              No     No        0.666667
# 3           No  0.147169      No              No     No        0.000000
# 4           No  0.141132      No              No     No        0.933333
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0           1.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2           1.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for col in df.columns:
    if is_num(df[col]):
        continue
    else:
        df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    HeartDisease       BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  0.055294        1                0       0        0.100000
# 1             0  0.100447        0                0       1        0.000000
# 2             0  0.175782        1                0       0        0.666667
# 3             0  0.147169        0                0       0        0.000000
# 4             0  0.141132        0                0       0        0.933333
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0           1.0            0    0            7     5         2
# 1           0.0            0    0           12     5         0
# 2           1.0            0    1            9     5         2
# 3           0.0            0    0           11     5         0
# 4           0.0            1    0            4     5         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %% [markdown]
# # Spliting Datasets

# %%
x = df.drop('HeartDisease', axis = 1)
y = df['HeartDisease']

# %% [markdown]
# # #Over Sampling

# %%
ag = RandomOverSampler(random_state = 50)

# %%
y.value_counts()
# Out:
# HeartDisease
# 0    274456
# 1     27261
# Name: count, dtype: int64

# %%
ag_x, ag_y = ag.fit_resample(x, y)

# %%
ag_y.value_counts()
# Out:
# HeartDisease
# 0    274456
# 1    274456
# Name: count, dtype: int64

# %% [markdown]
# # Stratified KFold Cross Validation

# %%
xtrain, xtest, ytrain, ytest = tts(ag_x, ag_y, test_size = 0.3, random_state = 50)

# %%
st = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 50)

# %%
for xtrain_index, xtest_index in st.split(ag_x,ag_y):
    xtrain, xtest = ag_x.iloc[xtrain_index], ag_x.iloc[xtest_index]
    ytrain, ytest = ag_y.iloc[xtrain_index], ag_y.iloc[xtest_index]

# %% [markdown]
# # Handling Class Imbalance

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 0    274456
# 1     27261
# Name: count, dtype: int64

# %%
not_heart_disease = (274456 / (27261 + 274456)) * 100
yes_heart_disease = (27261 / (27261 + 274456)) * 100
print('Not Heart Disease: {} percent of total people.'.format(not_heart_disease))
print('Suffering from Heart Disease: {} percent of total people.'.format(yes_heart_disease))
# Out:
# Not Heart Disease: 90.96471196518591 percent of total people.
# Suffering from Heart Disease: 9.03528803481408 percent of total people.

# %% [markdown]
# # Select K Best

# %%
from sklearn.feature_selection import SelectKBest

# %%
from sklearn.feature_selection import f_classif as fcf

# %%
skb = SelectKBest(score_func = fcf)

# %%
feature_score = skb.fit(ag_x, ag_y)

# %%
feature_score.scores_
# Out:
# array([  3516.24746924,  18420.54916791,   2534.21463512,  30373.19057072,
#         31569.73055078,    616.71401924,  46960.15544102,   9560.54157166,
#        132576.53273553,   3340.70510221,  34460.62207005,  12888.62352158,
#           277.03489871,    154.02427584,   1868.30146544,  18079.9721661 ,
#         10521.23766089])

# %%
col1 = pd.DataFrame(feature_score.scores_, columns = ['Feature Score'])
col2 = pd.DataFrame(ag_x.columns, columns = ['Feature Name'])
score = pd.concat([col1, col2], axis = 1)
score
# Out:
#     Feature Score      Feature Name
# 0     3516.247469               BMI
# 1    18420.549168           Smoking
# 2     2534.214635   AlcoholDrinking
# 3    30373.190571            Stroke
# 4    31569.730551    PhysicalHealth
# 5      616.714019      MentalHealth
# 6    46960.155441       DiffWalking
# 7     9560.541572               Sex
# 8   132576.532736       AgeCategory
# 9     3340.705102              Race
# 10   34460.622070          Diabetic
# 11   12888.623522  PhysicalActivity
# 12     277.034899         GenHealth
# 13     154.024276         SleepTime
# 14    1868.301465            Asthma
# 15   18079.972166     KidneyDisease
# 16   10521.237661        SkinCancer

# %%
score_sort = score.sort_values(by = 'Feature Score', ascending = False)
score_sort
# Out:
#     Feature Score      Feature Name
# 8   132576.532736       AgeCategory
# 6    46960.155441       DiffWalking
# 10   34460.622070          Diabetic
# 4    31569.730551    PhysicalHealth
# 3    30373.190571            Stroke
# 1    18420.549168           Smoking
# 15   18079.972166     KidneyDisease
# 11   12888.623522  PhysicalActivity
# 16   10521.237661        SkinCancer
# 7     9560.541572               Sex
# 0     3516.247469               BMI
# 9     3340.705102              Race
# 2     2534.214635   AlcoholDrinking
# 14    1868.301465            Asthma
# 5      616.714019      MentalHealth
# 12     277.034899         GenHealth
# 13     154.024276         SleepTime

# %%
score_sort.head(5)
# Out:
#     Feature Score    Feature Name
# 8   132576.532736     AgeCategory
# 6    46960.155441     DiffWalking
# 10   34460.622070        Diabetic
# 4    31569.730551  PhysicalHealth
# 3    30373.190571          Stroke

# %%
ag_x = ag_x[['AgeCategory']]

# %%
ag_x.head()
# Out:
#    AgeCategory
# 0            7
# 1           12
# 2            9
# 3           11
# 4            4

# %%
xtrain, xtest, ytrain, ytest = tts(ag_x, ag_y, test_size = 0.3, random_state = 50)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression()

# %%
log.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
log_pred = log.predict(xtest)
log_pred
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
log_acc = acc(ytest, log_pred)
log_acc
# Out:
# 0.6879592406815891

# %% [markdown]
# # Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestClassifier()

# %%
rf.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier()

# %%
rf_pred = rf.predict(xtest)
rf_pred
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
rf_acc = acc(ytest, rf_pred)
rf_acc
# Out:
# 0.6879592406815891

# %% [markdown]
# # Bernoulli Naive Bayes Classifier

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
bn = BernoulliNB()

# %%
bn.fit(xtrain, ytrain)
# Out:
# BernoulliNB()

# %%
bn_pred = bn.predict(xtest)
bn_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
bn_acc = acc(ytest, bn_pred)
bn_acc
# Out:
# 0.5329742400136026

# %% [markdown]
# # Gaussian Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gn = GaussianNB()

# %%
gn.fit(xtrain, ytrain)
# Out:
# GaussianNB()

# %%
gn_pred = gn.predict(xtest)
gn_pred
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
gn_acc = acc(ytest, gn_pred)
gn_acc
# Out:
# 0.6879592406815891

# %% [markdown]
# # Multinomial Naive Bayes Classifier

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mn = MultinomialNB()

# %%
mn.fit(xtrain, ytrain)
# Out:
# MultinomialNB()

# %%
mn_pred = mn.predict(xtest)
mn_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
mn_acc = acc(ytest, mn_pred)
mn_acc
# Out:
# 0.49929557792972784

# %% [markdown]
# # K-Nearest Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(xtrain, ytrain)
# Out:
# KNeighborsClassifier()

# %%
knn_pred = knn.predict(xtest)
knn_pred
# Out:
# array([0, 0, 1, ..., 1, 0, 0])

# %%
knn_acc = acc(ytest, knn_pred)
knn_acc
# Out:
# 0.6636627518612531

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dt.predict(xtest)
dt_pred
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
dt_acc = acc(ytest, dt_pred)
dt_acc
# Out:
# 0.6879592406815891

# %% [markdown]
# # Model Selection

# %%
compare_acc = pd.DataFrame({'Model': ['Logistic Regression', 'Random Forest', 'Bernoulli Naive Bayes', 'Gaussian Naive Bayes', 'Multinomial Naive Bayes', 'K Nearest Neighbors', 'Decision Tree'], 'Accuracy': [log_acc, rf_acc, bn_acc, gn_acc, mn_acc, knn_acc, dt_acc]})
compare_acc
# Out:
#                      Model  Accuracy
# 0      Logistic Regression  0.687959
# 1            Random Forest  0.687959
# 2    Bernoulli Naive Bayes  0.532974
# 3     Gaussian Naive Bayes  0.687959
# 4  Multinomial Naive Bayes  0.499296
# 5      K Nearest Neighbors  0.663663
# 6            Decision Tree  0.687959

# %%
compare_acc_sort = compare_acc.sort_values(by = 'Accuracy', ascending = False)
compare_acc_sort
# Out:
#                      Model  Accuracy
# 0      Logistic Regression  0.687959
# 1            Random Forest  0.687959
# 3     Gaussian Naive Bayes  0.687959
# 6            Decision Tree  0.687959
# 5      K Nearest Neighbors  0.663663
# 2    Bernoulli Naive Bayes  0.532974
# 4  Multinomial Naive Bayes  0.499296

# %%
plt.figure(figsize = (25, 10))
sns.barplot(x = 'Model', y = 'Accuracy', data = compare_acc_sort, palette = 'rainbow', edgecolor = 'black', linewidth = 2.0).set_title('Model Accuracy Comparison', fontsize = 50, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', loc = 'center', pad = 10.0, weight = 'bold')
plt.xlabel('Model', fontsize = 40, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', labelpad = 10.0)
plt.ylabel('Accuracy', fontsize = 40, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', labelpad = 10.0)
plt.xticks(fontsize = 30, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', rotation = 0)
plt.yticks(fontsize = 25, fontweight = 'bold', fontname = 'Freestyle Script', color = 'black', rotation = 0)
plt.show()

# %% [markdown]
# # Load and Save Model

# %%
import joblib as jb

# %%
jb.dump(rf, 'heart_disease_model')
# Out:
# ['heart_disease_model']

# %%
model = jb.load('heart_disease_model')

# %% [markdown]
# # Gradio Diployment

# %%
import gradio as gr

# %%
def predict_heart_disease(nm_x):
    HeartDisease = model.predict([[nm_x]])
    return HeartDisease

# %%
interface = gr.Interface(
    fn = predict_heart_disease,
    inputs = ['number'],
    outputs = ['number']
).launch(share = False)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
